# %%
import pandas as pd

# %%
df=pd.read_csv("rss_opportunities.csv")

# %%
df.sample(10)
# Out:
#                   category                                              title  \
# 237  Talent Identification  Indian women’s football coach scouts for talen...
# 0              Gov Schemes  Khelo India under-performing—missing athletes,...
# 246   Private Scholarships  Trump prepares sweeping order on college sport...
# 20             Gov Schemes  Meghalaya CM hands over sports scholarship to ...
# 64        Selection Trials  Kumkum Mohod’s Breakthrough: Teen Prodigy Tops...
# 309   Private Scholarships  James Robinson Pathway to Officiating Post-Sec...
# 55        Selection Trials  Glasgow Commonwealth Games: Trials in Ranchi t...
# 134      Sports Quota Jobs  ‘Vacancies unfilled for 8-10 years’: Haryana O...
# 186  Talent Identification  How is ScoutEdge Changing Athlete Scouting in ...
# 162      Sports Quota Jobs  Assam Rifles Sports Quota Recruitment 2023 Not...
#
#                                                   link  image_url  \
# ...
